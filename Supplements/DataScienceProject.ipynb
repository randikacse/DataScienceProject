# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math 
import scipy.stats as stat
# %matplotlib inline
#vtypes2012read = pd.read_csv('road_accident_data_by_vehicle_type_2012.csv')
vtypes2012read = pd.read_csv('road_accident_data_by_vehicle_type_2012.csv')

vtypes2012read.describe()
# Out:
#           Motor Car  Dual Purpose Vehicle        Lorry        Cycle  \
# count     26.000000             26.000000    26.000000    26.000000
# mean     775.615385            668.384615   577.153846   179.153846
# std     2130.677283           1734.890085  1465.110472   445.979254
# min        1.000000              6.000000     2.000000     9.000000
# 25%       33.000000             78.500000   100.000000    29.250000
# 50%       92.000000            196.000000   167.000000    65.000000
# 75%      320.000000            363.500000   345.250000   152.000000
# max    10083.000000           8689.000000  7503.000000  2329.000000
#
#        Motor Cycle/Moped  Three wheeler  Articulated Vehicle, prime mover  \
# count          26.000000      26.000000                         26.000000
# mean         1264.076923     770.000000                         31.769231
# std          3172.890240    1973.489701                         86.824102
# ...

# %% [markdown]
# Segragating totals and data from vtypes2012

# %%
vtypes2012data = vtypes2012read[['Location','Motor Car','Dual Purpose Vehicle','Lorry','Cycle','Motor Cycle/Moped','Three wheeler','Articulated Vehicle, prime mover','SLT Bus','Private Bus','Intercity Bus','Land Vehicle/Tractor','Animal drawn vehicle or rider on animal','Other']]
vtypes2012data

vtypes2012ctotals = vtypes2012read.loc[25:, 'Motor Car':'Other']
vtypes2012ctotals
# Out:
#     Motor Car  Dual Purpose Vehicle  Lorry  Cycle  Motor Cycle/Moped  \
# 25      10083                  8689   7503   2329              16433
#
#     Three wheeler  Articulated Vehicle, prime mover  SLT Bus  Private Bus  \
# 25          10010                               413     1163         4151
#
#     Intercity Bus  Land Vehicle/Tractor  \
# 25             45                   576
#
#     Animal drawn vehicle or rider on animal  Other
# 25                                       14    178

# %%
vtypes2012rtotals = vtypes2012read.loc[0:24 ,['Location','Total']]
vtypes2012rtotals
# Out:
#                                              Location  Total
# 0                                             Ampara    1219
# 1                                       Anuradhapura    2000
# 2           Badulla (Badulla & Bandarawela Divisions)   1039
# 3                                         Batticaloa     505
# 4                Chilaw (Chilaw & Puttalam Divisions)   1511
# 5   Colombo (Colombo-South, North, Central, Mt. La...  16549
# 6                  Galle (Galle & Elpitiya Divisions)   3702
# 7     Gampaha (Gampaha, Negombo & Kelaniya Divisions)  10384
# 8                     Jaffna (Jaffna & KKS Divisions)    549
# 9            Kalutara (Kalutara & Panadura Divisions)   3220
# 10                  Kandy (Kandy & Gampola Divisions)   4156
# 11           Kegalle (Kegalle & Seethawaka Divisions)   2374
# 12     Kilinochchi (Kilinochchi & Mankulam Divisions)    414
# 13  Kurunegala (Kurunegala, Kuliyapitiya & Nikawer...   3645
# ...

# %%
plt.style.use('ggplot')
vtypes2012ctotals.T.plot(kind='bar')
plt.ylabel('No of accidents')
# Out:
# Text(0, 0.5, 'No of accidents')

# %%
vtypes2012ctotals.T.plot()
plt.ylabel('No of accidents')
# Out:
# Text(0, 0.5, 'No of accidents')
